# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisGuzman128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/el_profe_circulo_axel_guzman_0070.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Axel Guzman NL = 23 Fecha 25/marzo/2026 ❤
# ---
# # Calcular Area y perimetro de un circulo
# ---
# ![Logo de Markdown](https://github.com/LuisGuzman128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/blob/main/formulas%20del%20circulo.png?raw=true)
#
# ---
#
#
# ## Formula para calcular el Area
# $A=\pi*r^2$
#
# ## formula para calcular perimetro
# $P=2*\pi*r$
#
# ---
#
# ## Datos de entrada
# %r$ ?
# ---
# ## Diagrama de flujo en LucydChart
# ![Logo de Markdown](https://raw.githubusercontent.com/LuisGuzman128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/DF%20Area%20perimeetro%20circulo.png)

# %%
# calcular area y perimetro de un circulo
# variables A,P, r
# formulas A = pi*r^2 y P = 2* pi* r
# capturar rl valor de r
import math
print("calculo de area y perimetro de un circulo")
r = float(input("ingrese el valor del radio: "))
A = math.pi*r**2
P = 2*math.pi*r
print("el area del circulo es: ", A)
print("el perimetro del circulo es: ", P)
print("Axel Guzman NL = 23")
# Out:
# calculo de area y perimetro de un circulo
# ingrese el valor del radio: 5
# el area del circulo es:  78.53981633974483
# el perimetro del circulo es:  31.41592653589793
# Axel Guzman NL = 23

# %% [markdown]
# # Relacion entre codigo y DF en Tldraw
# ![Logo de Markdown](https://raw.githubusercontent.com/LuisGuzman128/EPPL-Area-y-perimetro-de-un-circulo-mis-imagenes/refs/heads/main/tldraw%20DF%20y%20codigo.png)
